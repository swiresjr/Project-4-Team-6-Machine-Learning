# %%
from ucimlrepo import fetch_ucirepo 
import pandas as pd
import matplotlib.pyplot as plt

# fetch dataset 
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697) 
  
# data (as pandas dataframes) 
X = predict_students_dropout_and_academic_success.data.features 
y = predict_students_dropout_and_academic_success.data.targets 
  
# metadata 
print(predict_students_dropout_and_academic_success.metadata) 
  
# variable information 
print(predict_students_dropout_and_academic_success.variables)
# Out:
# {'uci_id': 697, 'name': "Predict Students' Dropout and Academic Success", 'repository_url': 'https://archive.ics.uci.edu/dataset/697/predict+students+dropout+and+academic+success', 'data_url': 'https://archive.ics.uci.edu/static/public/697/data.csv', 'abstract': "A dataset created from a higher education institution (acquired from several disjoint databases) related to students enrolled in different undergraduate degrees, such as agronomy, design, education, nursing, journalism, management, social service, and technologies.\nThe dataset includes information known at the time of student enrollment (academic path, demographics, and social-economic factors) and the students' academic performance at the end of the first and second semesters. \nThe data is used to build classification models to predict students' dropout and academic sucess. The problem is formulated as a three category classification task, in which there is a strong imbalance towards one of the classes.", 'area': 'Social 
# ...

# %%
print(X.head())  # Display the first few rows of feature data
print(X.columns)  # List the column names
# Out:
#    Marital Status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
print(X["Mother's qualification"].unique())  # Display unique values
print(X["Mother's qualification"].value_counts())  # Check the counts for each level
# Out:
# [19  1 37 38  3  4 42  2 34 12 40  9  5 39 11 41 30 14 35 36  6 10 29 43
#  18 22 27 26 44]
# Mother's qualification
# 1     1069
# 37    1009
# 19     953
# 38     562
# 3      438
# 34     130
# 2       83
# 4       49
# 12      42
# 5       21
# 40       9
# 9        8
# 39       8
# 41       6
# 6        4
# 42       4
# 43       4
# 29       3
# 10       3
# 11       3
# 36       3
# 35       3
# 30       3
# 14       2
# 18       1
# 22       1
# 27       1
# 26       1
# 44       1
# Name: count, dtype: int64

# %%
# Fetch dataset
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697) 

# Extract feature data
X = predict_students_dropout_and_academic_success.data.features 
filtered_data = X[X["Mother's qualification"].isin([1, 37, 19, 38, 3, 34, 2])]

# Map numeric values to education level names
education_mapping = {
    1: "High School Only",
    37: "4th, 5th grade",
    19: "9th, 10th, 11th grade",
    38: "6th, 7th, 8th grade",
    3: "AA or certification",
    2: "Bachelor's"
}

# Check available columns
#print(X.columns)

filtered_data["Mother's qualification"] = filtered_data["Mother's qualification"].map(education_mapping)


if "Mother's qualification" in X.columns:
    # Count occurrences of each education level
    moms_schooling = filtered_data["Mother's qualification"].value_counts()

    # Plot the bar chart
    moms_schooling.plot.bar(color='tab:blue')
    plt.xlabel("Highest Level of Education")
    plt.ylabel("Number of Mothers")
    plt.title("Mother's Education Level")
    plt.xticks(rotation=45)  # Rotate labels for better readability
    plt.show()
# Out:
# /var/folders/c2/k1bbm6r51l3cqhcwy_2kg0bm0000gn/T/ipykernel_50008/3994979751.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data["Mother's qualification"] = filtered_data["Mother's qualification"].map(education_mapping)

# %%
print(X["Father's qualification"].unique())  # Display unique values
print(X["Father's qualification"].value_counts())  # Check the counts for each level
# Out:
# [12  3 37 38  1 19  5  4 34  2 39 11  9 36 26 40 14 20 35 41 22 13 29 43
#  18 42 10  6 30 25 44 33 27 31]
# Father's qualification
# 37    1209
# 19     968
# 1      904
# 38     702
# 3      282
# 34     112
# 2       68
# 4       39
# 12      38
# 39      20
# 5       18
# 11      10
# 36       8
# 9        5
# 40       5
# 22       4
# 30       4
# 14       4
# 29       3
# 35       2
# 41       2
# 43       2
# 10       2
# 6        2
# 26       2
# 25       1
# 27       1
# 33       1
# 44       1
# 20       1
# 42       1
# 18       1
# 13       1
# 31       1
# Name: count, dtype: int64

# %%
# Extract feature data
X = predict_students_dropout_and_academic_success.data.features 
filtered_data = X[X["Father's qualification"].isin([1, 37, 19, 38, 3, 34, 2])]

# Map numeric values to education level names
education_mapping = {
    1: "High School Only",
    37: "4th, 5th grade",
    19: "9th, 10th, 11th grade",
    38: "6th, 7th, 8th grade",
    3: "AA or certification",
    2: "Bachelor's"
}

# Check available columns
#print(X.columns)

filtered_data["Father's qualification"] = filtered_data["Father's qualification"].map(education_mapping)


if "Father's qualification" in X.columns:
    # Count occurrences of each education level
    moms_schooling = filtered_data["Father's qualification"].value_counts()

    # Plot the bar chart
    moms_schooling.plot.bar(color='tab:blue')
    plt.xlabel("Highest Level of Education")
    plt.ylabel("Number of Father's")
    plt.title("Father's Education Level")
    plt.xticks(rotation=45)  # Rotate labels for better readability
    plt.show()
# Out:
# /var/folders/c2/k1bbm6r51l3cqhcwy_2kg0bm0000gn/T/ipykernel_50008/1676171848.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data["Father's qualification"] = filtered_data["Father's qualification"].map(education_mapping)
